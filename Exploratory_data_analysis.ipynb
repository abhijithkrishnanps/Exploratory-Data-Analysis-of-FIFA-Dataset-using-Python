# %%
#Exploratory Data Analysis
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv("/content/drive/MyDrive/fifa_dataset.csv")
df.head()
# Out:
#        ID               Name  Age Nationality  Overall  Potential  \
# 0  158023           L. Messi   31   Argentina       94         94
# 1   20801  Cristiano Ronaldo   33    Portugal       94         94
# 2  190871          Neymar Jr   26      Brazil       92         93
# 3  193080             De Gea   27       Spain       91         93
# 4  192985       K. De Bruyne   27     Belgium       91         92
#
#                   Club     Value   Wage Preferred Foot  \
# 0         FC Barcelona  110500.0  565.0           Left
# 1             Juventus   77000.0  405.0          Right
# 2  Paris Saint-Germain  118500.0  290.0          Right
# 3    Manchester United   72000.0  260.0          Right
# 4      Manchester City  102000.0  355.0          Right
#
#    International Reputation  Skill Moves Position  Joined  \
# 0                       5.0          4.0       RF    2004
# 1                       5.0          5.0       ST    2018
# ...

# %%
df.tail()
# Out:
#            ID                Name  Age Nationality  Overall  Potential  \
# 18202  238813        J. Lundstram   19     England       47         65
# 18203  243165  N. Christoffersson   19      Sweden       47         63
# 18204  241638           B. Worman   16     England       47         67
# 18205  246268      D. Walker-Rice   17     England       47         66
# 18206  246269           G. Nugent   16     England       46         66
#
#                    Club  Value  Wage Preferred Foot  International Reputation  \
# 18202   Crewe Alexandra   60.0   1.0          Right                       1.0
# 18203    Trelleborgs FF   60.0   1.0          Right                       1.0
# 18204  Cambridge United   60.0   1.0          Right                       1.0
# 18205   Tranmere Rovers   60.0   1.0          Right                       1.0
# 18206   Tranmere Rovers   60.0   1.0          Right                       1.0
#
# ...

# %%
df.isnull().sum()
# Out:
# ID                            0
# Name                          0
# Age                           0
# Nationality                   0
# Overall                       0
# Potential                     0
# Club                        241
# Value                       252
# Wage                          0
# Preferred Foot                0
# International Reputation     48
# Skill Moves                  48
# Position                      0
# Joined                        0
# Contract Valid Until        289
# Height                        0
# Weight                        0
# Release Clause                0
# dtype: int64

# %%
df.dtypes
# Out:
# ID                            int64
# Name                         object
# Age                           int64
# Nationality                  object
# Overall                       int64
# Potential                     int64
# Club                         object
# Value                       float64
# Wage                        float64
# Preferred Foot               object
# International Reputation    float64
# Skill Moves                 float64
# Position                     object
# Joined                        int64
# Contract Valid Until         object
# Height                      float64
# Weight                      float64
# Release Clause              float64
# dtype: object

# %%
df.describe()
# Out:
#                   ID           Age       Overall     Potential          Value  \
# count   18207.000000  18207.000000  18207.000000  18207.000000   17955.000000
# mean   214298.338606     25.122206     66.238699     71.307299    2444.530214
# std     29965.244204      4.669943      6.908930      6.136496    5626.715434
# min        16.000000     16.000000     46.000000     48.000000      10.000000
# 25%    200315.500000     21.000000     62.000000     67.000000     325.000000
# 50%    221759.000000     25.000000     66.000000     71.000000     700.000000
# 75%    236529.500000     28.000000     71.000000     75.000000    2100.000000
# max    246620.000000     45.000000     94.000000     95.000000  118500.000000
#
#                Wage  International Reputation   Skill Moves        Joined  \
# count  18207.000000              18159.000000  18159.000000  18207.000000
# mean       9.731312                  1.113222      2.361308   2016.420607
# ...

# %%
sns.boxplot(x=df['Age'])
plt.show()

# %%
sns.boxplot(x=df['Height'])
plt.show()

# %%
sns.histplot(df['Age'], kde=True)
plt.title("Age Distribution")
plt.show()

# %%
sns.countplot(y=df['Nationality'], order=df['Nationality'].value_counts().head(10).index)
plt.title("Top 10 Nationalities")
plt.show()

# %%
df['AgeGroup'] = pd.cut(df['Age'], bins=[15,20,25,30,35,40])
print(df['AgeGroup'].value_counts())
# Out:
# AgeGroup
# (20, 25]    6772
# (25, 30]    5526
# (15, 20]    3327
# (30, 35]    2289
# (35, 40]     284
# Name: count, dtype: int64

# %%
print("Tallest players:")
print(df[['Name','Height']].sort_values('Height', ascending=False).head())
# Out:
# Tallest players:
#                       Name    Height
# 11614              T. Holý  6.750000
# 17927            D. Hodzic  6.750000
# 4189   V. Milinković-Savić  6.666667
# 11403           A. Noppert  6.666667
# 16923            S. Brolin  6.666667

# %%
print("\nShortest players:")
print(df[['Name','Height']].sort_values('Height', ascending=True).head())
# Out:
# Shortest players:
#                 Name    Height
# 17157   K. Yamaguchi  5.083333
# 6584     H. Nakagawa  5.083333
# 6275      N. Barrios  5.083333
# 8536   C. Songkrasin  5.166667
# 5828      C. Techera  5.166667

# %%
print(df['Weight'].describe())
# Out:
# count    18207.000000
# mean       165.979129
# std         15.572775
# min        110.000000
# 25%        154.000000
# 50%        165.000000
# 75%        176.000000
# max        243.000000
# Name: Weight, dtype: float64

# %%
print(df['Preferred Foot'].value_counts())
# Out:
# Preferred Foot
# Right    13996
# Left      4211
# Name: count, dtype: int64

# %%
print(df['Club'].value_counts().head(10))
# Out:
# Club
# RC Celta                   33
# Everton                    33
# Valencia CF                33
# Borussia Dortmund          33
# TSG 1899 Hoffenheim        33
# Wolverhampton Wanderers    33
# AS Monaco                  33
# Real Madrid                33
# Atlético Madrid            33
# Manchester United          33
# Name: count, dtype: int64

# %%
print(df.groupby('Club')['Overall'].mean().sort_values(ascending=False).head(10))
# Out:
# Club
# Juventus               82.280000
# Napoli                 80.000000
# Inter                  79.750000
# Real Madrid            78.242424
# Milan                  78.074074
# FC Barcelona           78.030303
# Paris Saint-Germain    77.433333
# Roma                   77.423077
# Manchester United      77.242424
# FC Bayern München      77.000000
# Name: Overall, dtype: float64

# %%
print(df.groupby('Club')['Wage'].mean().sort_values(ascending=False).head(10))
# Out:
# Club
# Real Madrid          152.030303
# FC Barcelona         146.575758
# Juventus             131.680000
# Manchester City      113.363636
# Manchester United    102.757576
# Chelsea               98.454545
# Liverpool             87.939394
# Tottenham Hotspur     79.484848
# FC Bayern München     78.827586
# Arsenal               78.424242
# Name: Wage, dtype: float64

# %%
print(df.groupby('Club')['Potential'].mean().sort_values(ascending=False).head(10))
# Out:
# Club
# Juventus               85.520000
# FC Barcelona           85.303030
# Real Madrid            84.636364
# Manchester City        83.909091
# FC Bayern München      83.655172
# Paris Saint-Germain    83.566667
# Napoli                 83.440000
# Manchester United      82.666667
# Chelsea                82.636364
# Milan                  82.555556
# Name: Potential, dtype: float64

# %%
df.head()
# Out:
#        ID               Name  Age Nationality  Overall  Potential  \
# 0  158023           L. Messi   31   Argentina       94         94
# 1   20801  Cristiano Ronaldo   33    Portugal       94         94
# 2  190871          Neymar Jr   26      Brazil       92         93
# 3  193080             De Gea   27       Spain       91         93
# 4  192985       K. De Bruyne   27     Belgium       91         92
#
#                   Club     Value   Wage Preferred Foot  \
# 0         FC Barcelona  110500.0  565.0           Left
# 1             Juventus   77000.0  405.0          Right
# 2  Paris Saint-Germain  118500.0  290.0          Right
# 3    Manchester United   72000.0  260.0          Right
# 4      Manchester City  102000.0  355.0          Right
#
#    International Reputation  Skill Moves Position  Joined  \
# 0                       5.0          4.0       RF    2004
# 1                       5.0          5.0       ST    2018
# ...

# %%
features = ['Age','Club','International Reputation','Skill Moves',
            'Overall','Potential','Value','Height','Weight']

target = 'Wage'

X = df[features]
y = df[target]

# One hot encoding for categorical columns
X = pd.get_dummies(X, columns=['Club'], drop_first=True)

# %%
X
# Out:
#        Age  International Reputation  Skill Moves  Overall  Potential  \
# 0       31                       5.0          4.0       94         94
# 1       33                       5.0          5.0       94         94
# 2       26                       5.0          5.0       92         93
# 3       27                       4.0          1.0       91         93
# 4       27                       4.0          4.0       91         92
# ...    ...                       ...          ...      ...        ...
# 18202   19                       1.0          2.0       47         65
# 18203   19                       1.0          2.0       47         63
# 18204   16                       1.0          2.0       47         67
# 18205   17                       1.0          2.0       47         66
# 18206   16                       1.0          2.0       46         66
#
#           Value    Height  Weight  Club_1. FC Heidenheim 1846  \
# 0      110500.0  5.583333   159.0                       False
# ...

# %%
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.impute import SimpleImputer
import pandas as pd # Ensure pandas is available for DataFrame operations

# Impute missing values in X_train and X_test
# Using mean strategy for numerical data
imputer = SimpleImputer(strategy='mean')

# Fit imputer on X_train and transform both X_train and X_test
X_train_imputed = imputer.fit_transform(X_train)
X_test_imputed = imputer.transform(X_test)

# Convert back to DataFrame, keeping column names and index
X_train_imputed = pd.DataFrame(X_train_imputed, columns=X_train.columns, index=X_train.index)
X_test_imputed = pd.DataFrame(X_test_imputed, columns=X_test.columns, index=X_test.index)

gbr_model = GradientBoostingRegressor(n_estimators=200, random_state=42)
gbr_model.fit(X_train_imputed, y_train)
# Out:
# GradientBoostingRegressor(n_estimators=200, random_state=42)

# %%
gbr_preds = gbr_model.predict(X_test_imputed)

# %%
print("Gradient Boosting Regressor - Mean Absolute Error (MAE):", mean_absolute_error(y_test, gbr_preds))
print("Gradient Boosting Regressor - R2 Score:", r2_score(y_test, gbr_preds))
# Out:
# Gradient Boosting Regressor - Mean Absolute Error (MAE): 3.369132890062162
# Gradient Boosting Regressor - R2 Score: 0.9131692176666499

# %%
print("Gradient Boosting Regressor - Training Score:", gbr_model.score(X_train_imputed, y_train))
print("Gradient Boosting Regressor - Testing Score:", gbr_model.score(X_test_imputed, y_test))
# Out:
# Gradient Boosting Regressor - Training Score: 0.9219447777350528
# Gradient Boosting Regressor - Testing Score: 0.9131692176666499
